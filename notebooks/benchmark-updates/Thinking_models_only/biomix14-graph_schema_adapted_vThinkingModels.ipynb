# %% [markdown]
# # Strategy 14. Naive strategy with graph schema
#
# Evaluating strategy 14 - naive approach with graph schema - on BioMix test-set. Using enhanced schema.

# %%
import os
from dotenv import load_dotenv
from tqdm import tqdm
import json
import pandas as pd

# Load environment variables from the .env file
load_dotenv()

# Retrieve the variables from the environment
neo4j_uri = os.getenv("NEO4J_URI")
neo4j_username = os.getenv("NEO4J_USERNAME")
neo4j_password = os.getenv("NEO4J_PASSWORD")

# Check if any variable is missing
if not all([neo4j_uri, neo4j_username, neo4j_password]):
    raise EnvironmentError("One or more environment variables are missing: NEO4J_URI, NEO4J_USERNAME, NEO4J_PASSWORD")

print(f"Accessing OpenTargets at {neo4j_uri} as user {neo4j_username}")
# Out:
# Accessing OpenTargets at bolt+s://pistoia.neo4j.rbsapp.net:7687 as user neo4j

# %% [markdown]
# Wrappers for LLMs and KG

# %%
# Langchain wrappers for different models

import re
from langchain_openai import ChatOpenAI
from langchain_anthropic import ChatAnthropic

chat_models = {}

def new_ChatModel(model):
    if re.search(r"^gpt", model):
        return ChatOpenAI(model = model)
    elif re.search(r"^o1", model):
        return ChatOpenAI(model = model, temperature = 1)
    elif re.search(r"^claude", model):
        return ChatAnthropic(model = model)
    else:
        raise ValueError(f"Unsupported model: {model}")

def ChatModel(model):
    if model in chat_models:
        return chat_models[model]
    else:
        chat_models[model] = new_ChatModel(model)
        return chat_models[model]

# %%
# Cypher data extraction

def extract_cypher(message):
    text = message
    pattern = r"```cypher(.*?)```"
    matches = re.findall(pattern, text, re.DOTALL)
    try:
        return [match.strip() for match in matches]
    except Exception:
        raise ValueError(f"Failed to parse: {message}")

  
from py2neo import Graph

graph = Graph(
    neo4j_uri,
    auth=(neo4j_username, neo4j_password)
)

# %%
# Some queries take a very long time to run. This will deal with timeout

import threading

class TimeoutThread(threading.Thread):
    def __init__(self, func, *args, **kwargs):
        threading.Thread.__init__(self)
        self.func = func
        self.args = args
        self.kwargs = kwargs
        self.result = None
        self.error = None

    def run(self):
        try:
            self.result = self.func(*self.args, **self.kwargs)
        except Exception as e:
            self.error = e

def run_with_timeout(func, timeout, *args, **kwargs):
    thread = TimeoutThread(func, *args, **kwargs)
    thread.start()
    thread.join(timeout)

    if thread.is_alive():
        raise TimeoutError("Function execution timed out")
    elif thread.error:
        raise thread.error
    return thread.result

# %%
# convenience functions for data retrieval from graph

import time

def query_cypher_graph(graph, query):
    return graph.query(query)

def query_graph(llm_output):
    try:
        cypher_query = extract_cypher(llm_output)
    except Exception as e:
        return [{
            "query":None,
            "success":False,
            "exception":str(e)
        }]

    cypher_results = []
    for query in cypher_query:
        try:
            start = time.time()
            result = run_with_timeout(query_cypher_graph, 20, graph, query)
            duration = time.time() - start
            cypher_results.append({
                "query":query,
                "success":True,
                "result": list(result),
                "time": duration
                })
        except Exception as e:
            cypher_results.append({
                "query":query,
                "success":False,
                "exception":str(e)
            })
    return cypher_results


def process_results(todo, llm_answers, cypher_results):
    results = []
    for t,llm,res in zip(todo, llm_answers, cypher_results):
        out = {
            "model" : t[0],
            "question" : t[1],
            "llm_answer" : llm,
            "cypher_output": res,
            "n_cypher_queries" : len(res)
        }
        if len(res) > 0:
            out.update({
                "query": res[0].get('query',''),
                "success": res[0]['success']
            })
            if res[0]['success']:
                out.update({
                    "results": res[0]['result'],
                    "time": res[0]['time'],
                    "count" : len(res[0]['result'])
                })
            else:
                out.update({
                    "error": res[0]['exception']
                })
        results.append(out)
    return results

# %% [markdown]
# ## Questions
#
# Loading from an extended biomix test-set

# %%
questions = pd.read_csv("../biomix/testset/biomix_true_false_selected_augmented.csv")

# %% [markdown]
# ## Running template-based query
#
# - 14b - enchanced schema

# %%
# Graph schema

from langchain_community.graphs import Neo4jGraph

graph = Neo4jGraph(url=neo4j_uri, username=neo4j_username, password=neo4j_password)
graph.refresh_schema()

normal_schema = graph.schema

enhanced_graph = Neo4jGraph(
    url=neo4j_uri,
    username=neo4j_username,
    password=neo4j_password,
    enhanced_schema=True,
)

enhanced_schema = enhanced_graph.schema

print(enhanced_schema)
# Out:
# /var/folders/xh/h0s_k2yj7vl5lcl4dyjlstxr0000gp/T/ipykernel_59194/506362744.py:5: LangChainDeprecationWarning: The class `Neo4jGraph` was deprecated in LangChain 0.3.8 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-neo4j package and should be used instead. To use it run `pip install -U :class:`~langchain-neo4j` and import as `from :class:`~langchain_neo4j import Neo4jGraph``.
#   graph = Neo4jGraph(url=neo4j_uri, username=neo4j_username, password=neo4j_password)
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The procedure has a deprecated field. ('config' used by 'apoc.meta.graphSample' is deprecated.)} {position: line: 1, column: 1, offset: 0} for query: "CALL apoc.meta.graphSample() YIELD nodes, relationships RETURN nodes, [rel in relationships | {name:apoc.any.property(rel, 'type'), count: apoc.any.property(rel, 'count')}] AS relationships"
# Node properties:
# - **Entity**
#   - `literature`: LIST Min Size: 1, Max Size: 1
#   - `score`: FLOAT Example: "0.03"
#   - `source`: STRING Example: "Open Targets"
#   - `licence`: STRING Example: "https://platform-docs.opentargets.org/licence"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "obi:1110122"
#   - `preferred_id`: STRING Example: "obi"
#   - `approvedSymbol`: STRING
#   - `biotype`: STRING
#   - `code`: STRING Example: "http://purl.obolibrary.org/obo/OBI_1110122"
#   - `name`: STRING Example: "pathological process"
#   - `description`: STRING Example: "Abnormal, harmful processes caused by or associate"
# - **ThingWithTaxon**
#   - `code`: STRING Example: "http://purl.obolibrary.org/obo/OBI_1110122"
#   - `name`: STRING Example: "pathological process"
#   - `description`: STRING Example: "Abnormal, harmful processes caused by or associate"
#   - `source`: STRING Example: "Open Targets"
#   - `licence`: STRING Example: "https://platform-docs.opentargets.org/licence"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "obi:1110122"
#   - `preferred_id`: STRING Example: "obi"
#   - `targetInModel`: STRING
#   - `targetInModelMgiId`: STRING
#   - `targetFromSourceId`: STRING
#   - `approvedSymbol`: STRING
#   - `biotype`: STRING
#   - `modelPhenotypeLabel`: STRING
# - **DiseaseOrPhenotypicFeature**
#   - `code`: STRING Example: "http://purl.obolibrary.org/obo/OBI_1110122"
#   - `name`: STRING Example: "pathological process"
#   - `description`: STRING Example: "Abnormal, harmful processes caused by or associate"
#   - `source`: STRING Example: "Open Targets"
#   - `licence`: STRING Example: "https://platform-docs.opentargets.org/licence"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "obi:1110122"
#   - `preferred_id`: STRING Example: "obi"
#   - `modelPhenotypeLabel`: STRING
# - **Disease**
#   - `code`: STRING Example: "http://purl.obolibrary.org/obo/OBI_1110122"
#   - `name`: STRING Example: "pathological process"
#   - `description`: STRING Example: "Abnormal, harmful processes caused by or associate"
#   - `source`: STRING Example: "Open Targets"
#   - `licence`: STRING Example: "https://platform-docs.opentargets.org/licence"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "obi:1110122"
#   - `preferred_id`: STRING Example: "obi"
# - **Obi.Disease**
#   - `code`: STRING Available options: ['http://purl.obolibrary.org/obo/OBI_1110122', 'http://purl.obolibrary.org/obo/OBI_0001621', 'http://purl.obolibrary.org/obo/OBI_0001620', 'http://purl.obolibrary.org/obo/OBI_1110021']
#   - `name`: STRING Available options: ['pathological process', 'longitude', 'latitude', 'infect']
#   - `description`: STRING Available options: ['Abnormal, harmful processes caused by or associate', 'A measurement that is the measure of the longitude', 'A measurement that is the measure of the latitude ', 'The detrimental process in which an infectious age']
#   - `source`: STRING Available options: ['Open Targets']
#   - `licence`: STRING Available options: ['https://platform-docs.opentargets.org/licence']
#   - `version`: STRING Available options: ['22.11']
#   - `id`: STRING Available options: ['obi:1110122', 'obi:0001621', 'obi:0001620', 'obi:1110021']
#   - `preferred_id`: STRING Available options: ['obi']
# - **BiologicalEntity**
#   - `code`: STRING Example: "http://purl.obolibrary.org/obo/OBI_1110122"
#   - `name`: STRING Example: "pathological process"
#   - `description`: STRING Example: "Abnormal, harmful processes caused by or associate"
#   - `source`: STRING Example: "Open Targets"
#   - `licence`: STRING Example: "https://platform-docs.opentargets.org/licence"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "obi:1110122"
#   - `preferred_id`: STRING Example: "obi"
#   - `targetInModel`: STRING
#   - `targetInModelMgiId`: STRING
#   - `targetFromSourceId`: STRING
#   - `approvedSymbol`: STRING
#   - `biotype`: STRING
#   - `modelPhenotypeLabel`: STRING
# - **NamedThing**
#   - `code`: STRING Example: "http://purl.obolibrary.org/obo/OBI_1110122"
#   - `name`: STRING Example: "pathological process"
#   - `description`: STRING Example: "Abnormal, harmful processes caused by or associate"
#   - `source`: STRING Example: "Open Targets"
#   - `licence`: STRING Example: "https://platform-docs.opentargets.org/licence"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "obi:1110122"
#   - `preferred_id`: STRING Example: "obi"
#   - `targetInModel`: STRING
#   - `targetInModelMgiId`: STRING
#   - `targetFromSourceId`: STRING
#   - `approvedSymbol`: STRING
#   - `biotype`: STRING
#   - `modelPhenotypeLabel`: STRING
# - **Ncit.Disease**
#   - `code`: STRING Available options: ['http://purl.obolibrary.org/obo/NCIT_C74532', 'http://purl.obolibrary.org/obo/NCIT_C117245', 'http://purl.obolibrary.org/obo/NCIT_C95746']
#   - `name`: STRING Available options: ['nervousness', 'decreased attention', 'sleepiness']
#   - `description`: STRING Available options: ['An uneasy psychological state; the anxious feeling', 'Impaired ability to focus on a subject or idea.', 'The sensation of struggling to remain awake.']
#   - `source`: STRING Available options: ['Open Targets']
#   - `licence`: STRING Available options: ['https://platform-docs.opentargets.org/licence']
#   - `version`: STRING Available options: ['22.11']
#   - `id`: STRING Available options: ['ncit:C74532', 'ncit:C117245', 'ncit:C95746']
#   - `preferred_id`: STRING Available options: ['ncit']
# - **Mondo.Disease**
#   - `code`: STRING Example: "http://purl.obolibrary.org/obo/MONDO_0000385"
#   - `name`: STRING Example: "benign digestive system neoplasm"
#   - `source`: STRING Available options: ['Open Targets']
#   - `licence`: STRING Available options: ['https://platform-docs.opentargets.org/licence']
#   - `version`: STRING Available options: ['22.11']
#   - `id`: STRING Example: "mondo:0000385"
#   - `preferred_id`: STRING Available options: ['mondo']
#   - `description`: STRING Example: "A non-metastasizing neoplasm arising from any part"
# - **Association**
#   - `literature`: LIST Min Size: 1, Max Size: 1
#   - `score`: FLOAT Example: "0.03"
#   - `source`: STRING Example: "europepmc"
#   - `licence`: STRING Example: "CC BY-NC 4.0"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "e1dc736fdce96afef5df978522894e9ee54ee710"
#   - `preferred_id`: STRING Example: "id"
# - **GeneToDiseaseAssociation**
#   - `literature`: LIST Min Size: 1, Max Size: 1
#   - `score`: FLOAT Example: "0.03"
#   - `source`: STRING Example: "europepmc"
#   - `licence`: STRING Example: "CC BY-NC 4.0"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "e1dc736fdce96afef5df978522894e9ee54ee710"
#   - `preferred_id`: STRING Example: "id"
# - **Literature.GeneToDiseaseAssociation**
#   - `literature`: LIST Min Size: 1, Max Size: 1
#   - `score`: FLOAT Example: "0.03"
#   - `source`: STRING Example: "europepmc"
#   - `licence`: STRING Example: "CC BY-NC 4.0"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "e1dc736fdce96afef5df978522894e9ee54ee710"
#   - `preferred_id`: STRING Example: "id"
# - **AnimalModel.GeneToDiseaseAssociation**
#   - `literature`: LIST Min Size: 1, Max Size: 11
#   - `score`: FLOAT Example: "0.4947"
#   - `source`: STRING Example: "impc"
#   - `licence`: STRING Example: "NA"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "1ed93ef5539f388a1423ba9b98a7b71f610d2a10"
#   - `preferred_id`: STRING Example: "id"
# - **Hp.Disease**
#   - `code`: STRING Example: "http://purl.obolibrary.org/obo/HP_0002751"
#   - `name`: STRING Example: "Kyphoscoliosis"
#   - `description`: STRING Example: "An abnormal curvature of the spine in both a coron"
#   - `source`: STRING Available options: ['Open Targets']
#   - `licence`: STRING Available options: ['https://platform-docs.opentargets.org/licence']
#   - `version`: STRING Available options: ['22.11']
#   - `id`: STRING Example: "hp:0002751"
#   - `preferred_id`: STRING Available options: ['hp']
# - **RnaExpression.GeneToDiseaseAssociation**
#   - `score`: FLOAT Example: "0.04389890211572866"
#   - `source`: STRING Example: "expression_atlas"
#   - `licence`: STRING Example: "CC BY 4.0"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "00019f5ecfc23eeddacf2a7c1a2a51a55620e7ff"
#   - `preferred_id`: STRING Example: "id"
#   - `literature`: LIST Min Size: 1, Max Size: 1
# - **Oba.Disease**
#   - `code`: STRING Example: "http://purl.obolibrary.org/obo/OBA_2001015"
#   - `name`: STRING Example: "age of onset of childhood onset asthma"
#   - `description`: STRING Example: "The age at which childhood onset asthma manifestat"
#   - `source`: STRING Available options: ['Open Targets']
#   - `licence`: STRING Available options: ['https://platform-docs.opentargets.org/licence']
#   - `version`: STRING Available options: ['22.11']
#   - `id`: STRING Example: "oba:2001015"
#   - `preferred_id`: STRING Available options: ['oba']
# - **Gene**
#   - `targetInModel`: STRING Example: "Eya1"
#   - `targetInModelMgiId`: STRING Example: "MGI:109344"
#   - `targetFromSourceId`: STRING Example: "ENSG00000104313"
#   - `source`: STRING Example: "Open Targets"
#   - `licence`: STRING Example: "https://platform-docs.opentargets.org/licence"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "ensembl:ENSMUSG00000025932"
#   - `preferred_id`: STRING Example: "ensembl"
#   - `approvedSymbol`: STRING
#   - `biotype`: STRING
# - **MouseGene**
#   - `targetInModel`: STRING Example: "Eya1"
#   - `targetInModelMgiId`: STRING Example: "MGI:109344"
#   - `targetFromSourceId`: STRING Example: "ENSG00000104313"
#   - `source`: STRING Example: "Open Targets"
#   - `licence`: STRING Example: "https://platform-docs.opentargets.org/licence"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "ensembl:ENSMUSG00000025932"
#   - `preferred_id`: STRING Example: "ensembl"
# - **KnownDrug.GeneToDiseaseAssociation**
#   - `score`: FLOAT Example: "0.1"
#   - `source`: STRING Example: "chembl"
#   - `licence`: STRING Example: "CC BY-SA 3.0"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "99af831915f347fcb03e76c2f5ea7e2315bf77ce"
#   - `preferred_id`: STRING Example: "id"
# - **Doid.Disease**
#   - `code`: STRING Available options: ['http://purl.obolibrary.org/obo/DOID_13406', 'http://purl.obolibrary.org/obo/DOID_0050890', 'http://purl.obolibrary.org/obo/DOID_10718', 'http://purl.obolibrary.org/obo/DOID_1947', 'http://purl.obolibrary.org/obo/DOID_7551', 'http://purl.obolibrary.org/obo/DOID_10113']
#   - `name`: STRING Available options: ['pulmonary sarcoidosis', 'synucleinopathy', 'giardiasis', 'trichomoniasis', 'gonorrhea', 'trypanosomiasis']
#   - `description`: STRING Available options: ['Sarcoidosis affecting the lung parenchyma. It is c', 'A neurodegenerative disease that is characterized ', 'A parasitic protozoa infectious disease that invol', 'A parasitic protozoa infectious disease that is ca', 'A primary bacterial infectious disease that is a s']
#   - `source`: STRING Available options: ['Open Targets']
#   - `licence`: STRING Available options: ['https://platform-docs.opentargets.org/licence']
#   - `version`: STRING Available options: ['22.11']
#   - `id`: STRING Available options: ['doid:13406', 'doid:0050890', 'doid:10718', 'doid:1947', 'doid:7551', 'doid:10113']
#   - `preferred_id`: STRING Available options: ['doid']
# - **Efo.Disease**
#   - `code`: STRING Example: "http://www.ebi.ac.uk/efo/EFO_0800502"
#   - `name`: STRING Example: "linoleoyl-docosahexaenoyl-glycerol (18:2/22:6) [1]"
#   - `description`: STRING Example: "Quantification of the amount of linoleoyl-docosahe"
#   - `source`: STRING Example: "Open Targets"
#   - `licence`: STRING Example: "https://platform-docs.opentargets.org/licence"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "efo:0800502"
#   - `preferred_id`: STRING Example: "efo"
# - **PhenotypicFeature**
#   - `modelPhenotypeLabel`: STRING Example: "abnormal trigeminal nerve morphology"
#   - `source`: STRING Example: "Open Targets"
#   - `licence`: STRING Example: "https://platform-docs.opentargets.org/licence"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "mp:0001914"
#   - `preferred_id`: STRING Example: "mp"
# - **MousePhenotype**
#   - `modelPhenotypeLabel`: STRING Example: "abnormal trigeminal nerve morphology"
#   - `source`: STRING Example: "Open Targets"
#   - `licence`: STRING Example: "https://platform-docs.opentargets.org/licence"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "mp:0001914"
#   - `preferred_id`: STRING Example: "mp"
# - **Otar.Disease**
#   - `code`: STRING Available options: ['http://www.ebi.ac.uk/efo/OTAR_0000018', 'http://www.ebi.ac.uk/efo/OTAR_0000006', 'http://www.ebi.ac.uk/efo/OTAR_0000014', 'http://www.ebi.ac.uk/efo/OTAR_0000020', 'http://www.ebi.ac.uk/efo/OTAR_0000009', 'http://www.ebi.ac.uk/efo/OTAR_0000003', 'http://www.ebi.ac.uk/efo/OTAR_0000010', 'http://www.ebi.ac.uk/efo/OTAR_0000017', 'http://www.ebi.ac.uk/efo/OTAR_0000019']
#   - `name`: STRING Available options: ['genetic, familial or congenital disease', 'musculoskeletal or connective tissue disease', 'pregnancy or perinatal disease', 'nutritional or metabolic disease', 'injury, poisoning or other complication', 'cyst', 'respiratory or thoracic disease', 'reproductive system or breast disease', 'familial disease']
#   - `description`: STRING Available options: ['A disease caused by genetic modifications inherite', 'A disease involving the musculoskeletal or connect', 'A disease occurring during pregnancy or shortly af', 'Damage inflicted on the body as the direct of indi', 'A sac-like closed membranous structure that may be', 'A disease affecting the respiratory system or othe', 'A disease involving the reproductive system or the', 'A disease occurring in or affecting members of a f']
#   - `source`: STRING Available options: ['Open Targets']
#   - `licence`: STRING Available options: ['https://platform-docs.opentargets.org/licence']
#   - `version`: STRING Available options: ['22.11']
#   - `id`: STRING Available options: ['otar:0000018', 'otar:0000006', 'otar:0000014', 'otar:0000020', 'otar:0000009', 'otar:0000003', 'otar:0000010', 'otar:0000017', 'otar:0000019']
#   - `preferred_id`: STRING Available options: ['otar']
# - **HumanGene**
#   - `approvedSymbol`: STRING Example: "FEZ2"
#   - `biotype`: STRING Example: "protein_coding"
#   - `source`: STRING Example: "Open Targets"
#   - `licence`: STRING Example: "https://platform-docs.opentargets.org/licence"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "ensembl:ENSG00000171055"
#   - `preferred_id`: STRING Example: "ensembl"
# - **Orphanet.Disease**
#   - `code`: STRING Example: "http://www.orpha.net/ORDO/Orphanet_158684"
#   - `name`: STRING Example: "Epidermolysis bullosa simplex with pyloric atresia"
#   - `description`: STRING Example: "Epidermolysis bullosa simplex with pyloric atresia"
#   - `source`: STRING Available options: ['Open Targets']
#   - `licence`: STRING Available options: ['https://platform-docs.opentargets.org/licence']
#   - `version`: STRING Available options: ['22.11']
#   - `id`: STRING Example: "orphanet:158684"
#   - `preferred_id`: STRING Available options: ['orphanet']
# - **SomaticMutation.GeneToDiseaseAssociation**
#   - `literature`: LIST Min Size: 1, Max Size: 8
#   - `score`: FLOAT Example: "0.25"
#   - `source`: STRING Example: "cancer_gene_census"
#   - `licence`: STRING Example: "Commercial use for Open Targets"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "00bb9bb991a5d157ac87eb0a0a858d3225e91f7e"
#   - `preferred_id`: STRING Example: "id"
# - **AffectedPathway.GeneToDiseaseAssociation**
#   - `literature`: LIST Min Size: 1, Max Size: 21
#   - `score`: FLOAT Example: "1.0"
#   - `source`: STRING Example: "reactome"
#   - `licence`: STRING Example: "CC BY 4.0"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "0573156c99191306506c7d365c089e90481066e2"
#   - `preferred_id`: STRING Example: "id"
# - **GoTerm**
#   - `name`: STRING Example: "adenosine 3,5-bisphosphate transmembrane transport"
#   - `source`: STRING Example: "Open Targets"
#   - `licence`: STRING Example: "https://platform-docs.opentargets.org/licence"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "go:0071106"
#   - `preferred_id`: STRING Example: "go"
# - **GeneticAssociation.GeneToDiseaseAssociation**
#   - `score`: FLOAT Example: "0.35"
#   - `source`: STRING Example: "eva"
#   - `licence`: STRING Example: "EMBL-EBI terms of use"
#   - `version`: STRING Example: "22.11"
#   - `id`: STRING Example: "4c75fa3ffc3e72f7b7496fd13377a701dac6e0e7"
#   - `preferred_id`: STRING Example: "id"
# - **Ogms.Disease**
#   - `code`: STRING Available options: ['http://purl.obolibrary.org/obo/OGMS_0000063']
#   - `name`: STRING Available options: ['disease course']
#   - `description`: STRING Available options: ['The totality of all processes through which a give']
#   - `source`: STRING Available options: ['Open Targets']
#   - `licence`: STRING Available options: ['https://platform-docs.opentargets.org/licence']
#   - `version`: STRING Available options: ['22.11']
#   - `id`: STRING Available options: ['ogms:0000063']
#   - `preferred_id`: STRING Available options: ['ogms']
# - **_GraphConfig**
#   - `_objectPropertyLabel`: STRING Available options: ['Relationship']
#   - `_rangeRel`: STRING Available options: ['RANGE']
#   - `_classLabel`: STRING Available options: ['Class']
#   - `_subClassOfRel`: STRING Available options: ['SCO']
#   - `_handleMultival`: INTEGER Min: 0, Max: 0
#   - `_dataTypePropertyLabel`: STRING Available options: ['Property']
#   - `_subPropertyOfRel`: STRING Available options: ['SPO']
#   - `_handleRDFTypes`: INTEGER Min: 0, Max: 0
#   - `_classNamePropName`: STRING Available options: ['name']
#   - `_handleVocabUris`: INTEGER Min: 0, Max: 0
#   - `_applyNeo4jNaming`: BOOLEAN
#   - `_relNamePropName`: STRING Available options: ['name']
#   - `_domainRel`: STRING Available options: ['DOMAIN']
#   - `_keepLangTag`: BOOLEAN
#   - `_keepCustomDataTypes`: BOOLEAN
# Relationship properties:
#
# The relationships:
# (:Entity)-[:IS_PART_OF]->(:Entity)
# (:Entity)-[:IS_PART_OF]->(:Association)
# (:Entity)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:Entity)-[:IS_PART_OF]->(:AffectedPathway.GeneToDiseaseAssociation)
# (:Entity)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:Entity)-[:IS_PART_OF]->(:RnaExpression.GeneToDiseaseAssociation)
# (:Entity)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:Entity)-[:IS_PART_OF]->(:AnimalModel.GeneToDiseaseAssociation)
# (:ThingWithTaxon)-[:IS_PART_OF]->(:Entity)
# (:ThingWithTaxon)-[:IS_PART_OF]->(:Association)
# (:ThingWithTaxon)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:ThingWithTaxon)-[:IS_PART_OF]->(:AnimalModel.GeneToDiseaseAssociation)
# (:ThingWithTaxon)-[:IS_PART_OF]->(:KnownDrug.GeneToDiseaseAssociation)
# (:ThingWithTaxon)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:ThingWithTaxon)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:ThingWithTaxon)-[:IS_PART_OF]->(:RnaExpression.GeneToDiseaseAssociation)
# (:ThingWithTaxon)-[:IS_PART_OF]->(:SomaticMutation.GeneToDiseaseAssociation)
# (:ThingWithTaxon)-[:IS_PART_OF]->(:AffectedPathway.GeneToDiseaseAssociation)
# (:DiseaseOrPhenotypicFeature)-[:IS_PART_OF]->(:Entity)
# (:DiseaseOrPhenotypicFeature)-[:IS_PART_OF]->(:Association)
# (:DiseaseOrPhenotypicFeature)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:DiseaseOrPhenotypicFeature)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:DiseaseOrPhenotypicFeature)-[:IS_PART_OF]->(:AnimalModel.GeneToDiseaseAssociation)
# (:DiseaseOrPhenotypicFeature)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:DiseaseOrPhenotypicFeature)-[:IS_PART_OF]->(:AffectedPathway.GeneToDiseaseAssociation)
# (:DiseaseOrPhenotypicFeature)-[:IS_PART_OF]->(:KnownDrug.GeneToDiseaseAssociation)
# (:DiseaseOrPhenotypicFeature)-[:IS_PART_OF]->(:SomaticMutation.GeneToDiseaseAssociation)
# (:DiseaseOrPhenotypicFeature)-[:IS_PART_OF]->(:RnaExpression.GeneToDiseaseAssociation)
# (:Disease)-[:IS_PART_OF]->(:Entity)
# (:Disease)-[:IS_PART_OF]->(:Association)
# (:Disease)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:Disease)-[:IS_PART_OF]->(:AnimalModel.GeneToDiseaseAssociation)
# (:Disease)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:Disease)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:Disease)-[:IS_PART_OF]->(:SomaticMutation.GeneToDiseaseAssociation)
# (:Disease)-[:IS_PART_OF]->(:KnownDrug.GeneToDiseaseAssociation)
# (:Disease)-[:IS_PART_OF]->(:AffectedPathway.GeneToDiseaseAssociation)
# (:Disease)-[:IS_PART_OF]->(:RnaExpression.GeneToDiseaseAssociation)
# (:Obi.Disease)-[:IS_PART_OF]->(:Entity)
# (:Obi.Disease)-[:IS_PART_OF]->(:Association)
# (:Obi.Disease)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:Obi.Disease)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:BiologicalEntity)-[:IS_PART_OF]->(:Entity)
# (:BiologicalEntity)-[:IS_PART_OF]->(:Association)
# (:BiologicalEntity)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:BiologicalEntity)-[:IS_PART_OF]->(:AnimalModel.GeneToDiseaseAssociation)
# (:BiologicalEntity)-[:IS_PART_OF]->(:KnownDrug.GeneToDiseaseAssociation)
# (:BiologicalEntity)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:BiologicalEntity)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:BiologicalEntity)-[:IS_PART_OF]->(:RnaExpression.GeneToDiseaseAssociation)
# (:BiologicalEntity)-[:IS_PART_OF]->(:SomaticMutation.GeneToDiseaseAssociation)
# (:BiologicalEntity)-[:IS_PART_OF]->(:AffectedPathway.GeneToDiseaseAssociation)
# (:NamedThing)-[:IS_PART_OF]->(:Entity)
# (:NamedThing)-[:IS_PART_OF]->(:Association)
# (:NamedThing)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:NamedThing)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:NamedThing)-[:IS_PART_OF]->(:AnimalModel.GeneToDiseaseAssociation)
# (:NamedThing)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:NamedThing)-[:IS_PART_OF]->(:KnownDrug.GeneToDiseaseAssociation)
# (:NamedThing)-[:IS_PART_OF]->(:SomaticMutation.GeneToDiseaseAssociation)
# (:NamedThing)-[:IS_PART_OF]->(:AffectedPathway.GeneToDiseaseAssociation)
# (:NamedThing)-[:IS_PART_OF]->(:RnaExpression.GeneToDiseaseAssociation)
# (:Mondo.Disease)-[:IS_PART_OF]->(:Entity)
# (:Mondo.Disease)-[:IS_PART_OF]->(:Association)
# (:Mondo.Disease)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:Mondo.Disease)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:Mondo.Disease)-[:IS_PART_OF]->(:AnimalModel.GeneToDiseaseAssociation)
# (:Mondo.Disease)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:Mondo.Disease)-[:IS_PART_OF]->(:KnownDrug.GeneToDiseaseAssociation)
# (:Mondo.Disease)-[:IS_PART_OF]->(:SomaticMutation.GeneToDiseaseAssociation)
# (:Mondo.Disease)-[:IS_PART_OF]->(:AffectedPathway.GeneToDiseaseAssociation)
# (:Mondo.Disease)-[:IS_PART_OF]->(:RnaExpression.GeneToDiseaseAssociation)
# (:Hp.Disease)-[:IS_PART_OF]->(:Entity)
# (:Hp.Disease)-[:IS_PART_OF]->(:Association)
# (:Hp.Disease)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:Hp.Disease)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:Hp.Disease)-[:IS_PART_OF]->(:KnownDrug.GeneToDiseaseAssociation)
# (:Hp.Disease)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:Hp.Disease)-[:IS_PART_OF]->(:SomaticMutation.GeneToDiseaseAssociation)
# (:Hp.Disease)-[:IS_PART_OF]->(:AnimalModel.GeneToDiseaseAssociation)
# (:Hp.Disease)-[:IS_PART_OF]->(:AffectedPathway.GeneToDiseaseAssociation)
# (:Hp.Disease)-[:IS_PART_OF]->(:RnaExpression.GeneToDiseaseAssociation)
# (:Gene)-[:IS_PART_OF]->(:Entity)
# (:Gene)-[:IS_PART_OF]->(:Association)
# (:Gene)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:Gene)-[:IS_PART_OF]->(:RnaExpression.GeneToDiseaseAssociation)
# (:Gene)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:Gene)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:Gene)-[:IS_PART_OF]->(:AffectedPathway.GeneToDiseaseAssociation)
# (:Gene)-[:IS_PART_OF]->(:SomaticMutation.GeneToDiseaseAssociation)
# (:Gene)-[:IS_PART_OF]->(:AnimalModel.GeneToDiseaseAssociation)
# (:Gene)-[:IS_PART_OF]->(:KnownDrug.GeneToDiseaseAssociation)
# (:Doid.Disease)-[:IS_PART_OF]->(:Entity)
# (:Doid.Disease)-[:IS_PART_OF]->(:Association)
# (:Doid.Disease)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:Doid.Disease)-[:IS_PART_OF]->(:KnownDrug.GeneToDiseaseAssociation)
# (:Doid.Disease)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:Doid.Disease)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:Efo.Disease)-[:IS_PART_OF]->(:Entity)
# (:Efo.Disease)-[:IS_PART_OF]->(:Association)
# (:Efo.Disease)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:Efo.Disease)-[:IS_PART_OF]->(:SomaticMutation.GeneToDiseaseAssociation)
# (:Efo.Disease)-[:IS_PART_OF]->(:KnownDrug.GeneToDiseaseAssociation)
# (:Efo.Disease)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:Efo.Disease)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:Efo.Disease)-[:IS_PART_OF]->(:RnaExpression.GeneToDiseaseAssociation)
# (:Efo.Disease)-[:IS_PART_OF]->(:AnimalModel.GeneToDiseaseAssociation)
# (:Efo.Disease)-[:IS_PART_OF]->(:AffectedPathway.GeneToDiseaseAssociation)
# (:Otar.Disease)-[:IS_PART_OF]->(:Entity)
# (:Otar.Disease)-[:IS_PART_OF]->(:Association)
# (:Otar.Disease)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:Otar.Disease)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:HumanGene)-[:IS_PART_OF]->(:Entity)
# (:HumanGene)-[:IS_PART_OF]->(:Association)
# (:HumanGene)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:HumanGene)-[:IS_PART_OF]->(:RnaExpression.GeneToDiseaseAssociation)
# (:HumanGene)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:HumanGene)-[:IS_PART_OF]->(:AnimalModel.GeneToDiseaseAssociation)
# (:HumanGene)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:HumanGene)-[:IS_PART_OF]->(:AffectedPathway.GeneToDiseaseAssociation)
# (:HumanGene)-[:IS_PART_OF]->(:KnownDrug.GeneToDiseaseAssociation)
# (:HumanGene)-[:IS_PART_OF]->(:SomaticMutation.GeneToDiseaseAssociation)
# (:Orphanet.Disease)-[:IS_PART_OF]->(:Entity)
# (:Orphanet.Disease)-[:IS_PART_OF]->(:Association)
# (:Orphanet.Disease)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:Orphanet.Disease)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)
# (:Orphanet.Disease)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:Orphanet.Disease)-[:IS_PART_OF]->(:AnimalModel.GeneToDiseaseAssociation)
# (:Orphanet.Disease)-[:IS_PART_OF]->(:KnownDrug.GeneToDiseaseAssociation)
# (:Orphanet.Disease)-[:IS_PART_OF]->(:AffectedPathway.GeneToDiseaseAssociation)
# (:Orphanet.Disease)-[:IS_PART_OF]->(:SomaticMutation.GeneToDiseaseAssociation)
# (:Orphanet.Disease)-[:IS_PART_OF]->(:RnaExpression.GeneToDiseaseAssociation)
# (:GoTerm)-[:IS_PART_OF]->(:Entity)
# (:GoTerm)-[:IS_PART_OF]->(:Association)
# (:GoTerm)-[:IS_PART_OF]->(:GeneToDiseaseAssociation)
# (:GoTerm)-[:IS_PART_OF]->(:GeneticAssociation.GeneToDiseaseAssociation)
# (:GoTerm)-[:IS_PART_OF]->(:KnownDrug.GeneToDiseaseAssociation)
# (:GoTerm)-[:IS_PART_OF]->(:Literature.GeneToDiseaseAssociation)

# %%
from langchain_core.prompts import PromptTemplate

# The following was adapted to guide LLM models (mainly gpt5 and up) for producing correct and extractable cypher queries

system_prompt_generic = """
You are a biological data scientist with expertise in knowledge graphs and Neo4j databases.

Your task: Generate syntactically correct Cypher queries to answer scientific questions about genes, diseases, and drugs.

Guidelines:
1. Always wrap your Cypher query in markdown code blocks with the 'cypher' language identifier:
```cypher
[insert cypher statement]
```

2. Use labels() for nodes, not type() - type() is only for relationships
3. Use case-insensitive matching for names: toLower() or CONTAINS with (?i) regex
4. Handle name variations (e.g., "Polycythemia Vera" vs "polycythemia vera")
5. Return relevant properties: id, name, score, source, etc.
6. Use ORDER BY and LIMIT when appropriate to manage result size
7. Add WHERE clauses to filter results effectively
8. For multiple label checks, use: WHERE any(l IN labels(node) WHERE l IN ['Label1', 'Label2'])
   NOT: WHERE (node:Label1 OR node:Label2)
9. For NULL handling in ORDER BY, use: ORDER BY coalesce(property, 0) DESC
   NOT: ORDER BY property DESC NULLS LAST

Common patterns:
- Gene to Disease: MATCH (g:Gene)-[:IS_PART_OF]->(assoc:GeneToDiseaseAssociation)<-[:IS_PART_OF]-(d:Disease)
- Check for property: WHERE g.approvedSymbol = 'GENE_NAME'
- Case-insensitive search: WHERE toLower(d.name) CONTAINS 'disease name'

{schema}

Output only the Cypher query wrapped in ```cypher code blocks. Do not include explanations unless requested.
"""




normal_schema_description = f"""\
This is graph schema:
--------------------------------------------
{normal_schema}
--------------------------------------------    
"""

enhanced_schema_description = f"""\
This is graph schema:
--------------------------------------------
{enhanced_schema}
--------------------------------------------    
"""

system_prompt_normal_schema = system_prompt_generic.format(schema = normal_schema_description)
system_prompt_enhanced_schema = system_prompt_generic.format(schema = enhanced_schema_description)

template_query = """
{question}
"""

user_template = PromptTemplate.from_template(template_query)

# %% [markdown]
# # Option 14b - enhanced schema

# %%
from langchain.schema import AIMessage, HumanMessage, SystemMessage
import openai
from anthropic import Anthropic

# Define base models to test
models_without_effort = ["gpt-4o"]  # does not have reasoning effort
models_with_effort = ["gpt-5.2-2025-12-11", "claude-sonnet-4-5-20250929"]

# Define reasoning effort levels
reasoning_efforts = ["medium", "high"]

# Create model configurations with effort levels
# Format: "model_name|effort_level" (e.g., "gpt-4o|medium", "gpt-4o|high")
models = models_without_effort + [f"{model}|{effort}" for model in models_with_effort for effort in reasoning_efforts]

niter = 1

# Create todo list: [(model_with_effort, question), ...]
todo = [(m, r['text']) for _, r in questions.iterrows() for m in models for _ in range(niter)]

def run_llm_14b(model_with_effort, question):

    try:
        
        #Check if this is a model with effort level (gpt-4o stays the same)
        if "|" in model_with_effort:
            model_name, effort = model_with_effort.split("|")
        else:
            model_name = model_with_effort # For GPT-4o
            effort = None
        
        if model_name == 'gpt-4o':
            llm = ChatModel(model = model_name)
            user_prompt = user_template.invoke({"question": question})

            messages = [
                SystemMessage(content=system_prompt_enhanced_schema),
                HumanMessage(content=user_prompt.text)
            ]
            result = llm.invoke(messages)
            return result.content
            
        # For OpenAI reasoningmodels
        elif model_name.startswith("gpt-5"):
            client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
            
            user_prompt = user_template.invoke({"question": question})
            
            response = client.chat.completions.create(
                model=model_name,
                messages=[
                    {"role": "system", "content": system_prompt_enhanced_schema},
                    {"role": "user", "content": user_prompt.text}
                ],
                reasoning_effort=effort
            )
            return response.choices[0].message.content
        
        # For Claude models with extended thinking
        elif model_name.startswith("claude"):
            client = Anthropic()
            
            user_prompt = user_template.invoke({"question": question})
            
            # Build messages - prefill thinking block for extended reasoning
            messages = [{"role": "user", "content": user_prompt.text}]
            
            
            response = client.messages.create(
                model=model_name,
                max_tokens=16000,  # Extended thinking may need more tokens
                system=system_prompt_enhanced_schema,
                messages=messages,
                thinking={
                    "type": "enabled",
                    "budget_tokens": 12000 if effort == "high" else 6000
                }
            )      
        
            # Extract text content (thinking blocks are separate)
            text_content = ""
            for block in response.content:
                if block.type == "text":
                    text_content += block.text
            
            return text_content
        
        else:
            raise ValueError(f"Unsupported model: {model_name}")
            
    except Exception as e:
        print(f"Error with {model_with_effort}: {e}")
        return None

# %%
llm_answers = []
for llm_model, question in tqdm(todo, desc="Prompting LLM"):
    llm_answers.append(run_llm_14b(llm_model, question))
# Out:
# Prompting LLM: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [1:38:35<00:00, 11.83s/it]

# %%
import time
for i, (llm_model, question) in enumerate(todo):
    if not llm_answers[i]:
        llm_answers[i] = run_llm_14b(llm_model, question)
        time.sleep(2)

# %%
cypher_results = []
for answer in tqdm(llm_answers, desc="Querying graph"):
    cypher_results.append(query_graph(answer))
# Out:
# Querying graph:   3%|████████▍                                                                                                                                                                                                                                                               | 16/500 [01:06<15:48,  1.96s/it]Transaction failed and will be retried in 1.17129858907491s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 1.0375143884556715s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 0.8728876802544485s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Querying graph:   8%|██████████████████████▏                                                                                                                                                                                                                                                 | 42/500 [03:16<32:03,  4.20s/it]Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (assocs) { ... }} {position: line: 27, column: 1, offset: 1025} for query: "WITH\n  'was' AS geneSym,\n  '(?i).*wiskott.*aldrich.*(syndrome)?.*' AS diseaseNameRegex\nMATCH (g)\nWHERE any(l IN labels(g) WHERE l IN ['Gene','HumanGene','MouseGene'])\n  AND toLower(coalesce(g.approvedSymbol, '')) = geneSym\nMATCH (d)\nWHERE any(l IN labels(d) WHERE l IN [\n    'Disease','DiseaseOrPhenotypicFeature',\n    'Mondo.Disease','Efo.Disease','Doid.Disease','Orphanet.Disease','Hp.Disease',\n    'Ncit.Disease','Obi.Disease','Otar.Disease','Ogms.Disease','Oba.Disease'\n  ])\n  AND d.name IS NOT NULL\n  AND d.name =~ diseaseNameRegex\nOPTIONAL MATCH (g)-[:IS_PART_OF]->(assoc)<-[:IS_PART_OF]-(d)\nWHERE any(l IN labels(assoc) WHERE l IN [\n  'GeneToDiseaseAssociation',\n  'Literature.GeneToDiseaseAssociation',\n  'AnimalModel.GeneToDiseaseAssociation',\n  'RnaExpression.GeneToDiseaseAssociation',\n  'GeneticAssociation.GeneToDiseaseAssociation',\n  'SomaticMutation.GeneToDiseaseAssociation',\n  'AffectedPathway.GeneToDiseaseAssociation',\n  'KnownDrug.GeneToDiseaseAssociation'\n])\nWITH g, d, collect(DISTINCT assoc) AS assocs\nCALL {\n  WITH assocs\n  WITH assocs, CASE WHEN size(assocs) = 0 THEN [null] ELSE assocs END AS assocs2\n  UNWIND assocs2 AS a\n  WITH a\n  ORDER BY coalesce(a.score, 0.0) DESC\n  WITH\n    collect(\n      CASE\n        WHEN a IS NULL THEN NULL\n        ELSE {\n          association_id: a.id,\n          association_labels: labels(a),\n          score: a.score,\n          source: a.source,\n          literature: a.literature,\n          licence: a.licence,\n          version: a.version\n        }\n      END\n    ) AS ev,\n    max(coalesce(a.score, 0.0)) AS mx,\n    collect(DISTINCT a.source) AS srcs\n  RETURN\n    [x IN ev WHERE x IS NOT NULL][0..20] AS evidence_top20,\n    coalesce(mx, 0.0) AS max_score,\n    [s IN srcs WHERE s IS NOT NULL] AS sources\n}\nRETURN\n  g.id AS gene_id,\n  g.approvedSymbol AS gene_symbol,\n  labels(g) AS gene_labels,\n  d.id AS disease_id,\n  d.name AS disease_name,\n  labels(d) AS disease_labels,\n  size(assocs) AS association_count,\n  max_score,\n  sources,\n  evidence_top20\nORDER BY association_count DESC, max_score DESC, disease_name ASC\nLIMIT 25;"
# Querying graph:  14%|█████████████████████████████████████▍                                                                                                                                                                                                                                  | 71/500 [05:33<30:06,  4.21s/it]Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (g, d) { ... }} {position: line: 17, column: 1, offset: 528} for query: "MATCH (g:Gene)\nWHERE toLower(g.approvedSymbol) = 'cxcr4'\n\nMATCH (d)\nWHERE any(l IN labels(d) WHERE l IN [\n  'Disease','DiseaseOrPhenotypicFeature','Mondo.Disease','Efo.Disease','Doid.Disease',\n  'Orphanet.Disease','Hp.Disease','Ncit.Disease','Obi.Disease','Otar.Disease','Ogms.Disease','Oba.Disease'\n])\nAND (\n  toLower(d.name) CONTAINS 'whim' OR\n  toLower(d.description) CONTAINS 'whim' OR\n  toLower(d.name) CONTAINS 'warts' OR\n  toLower(d.name) CONTAINS 'hypogammaglobulinemia' OR\n  toLower(d.name) CONTAINS 'myelokathexis'\n)\n\nCALL {\n  WITH g, d\n  OPTIONAL MATCH (g)-[:IS_PART_OF]->(assoc:GeneToDiseaseAssociation)<-[:IS_PART_OF]-(d)\n  RETURN\n    count(assoc) AS association_count,\n    collect(DISTINCT {\n      assoc_id: assoc.id,\n      assoc_score: assoc.score,\n      assoc_source: assoc.source,\n      assoc_version: assoc.version,\n      literature: assoc.literature\n    })[0..25] AS associations\n}\n\nRETURN\n  g { .id, .approvedSymbol, .targetFromSourceId, .biotype, .source, .version } AS gene,\n  d { .id, .name, .code, .source, .version } AS disease,\n  association_count,\n  associations\nORDER BY toLower(d.name) ASC\nLIMIT 25;"
# Querying graph:  14%|██████████████████████████████████████                                                                                                                                                                                                                                  | 72/500 [05:46<48:34,  6.81s/it]Transaction failed and will be retried in 1.0224579433304908s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 0.8558672094036203s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 0.981125258588683s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Querying graph:  15%|████████████████████████████████████████▋                                                                                                                                                                                                                               | 77/500 [06:32<51:10,  7.26s/it]Transaction failed and will be retried in 0.8447443598156278s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Querying graph:  42%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                                                                                                                                        | 211/500 [17:28<11:18,  2.35s/it]Transaction failed and will be retried in 0.8893877822268861s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Querying graph:  60%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                                        | 302/500 [28:52<38:54, 11.79s/it]Transaction failed and will be retried in 0.9080348435630833s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 0.9092272581142087s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Querying graph:  62%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                                                   | 312/500 [30:13<11:27,  3.66s/it]Transaction failed and will be retried in 0.9723111925420105s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 0.940736108407729s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 1.1782684900279037s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Querying graph:  63%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                                                                                | 317/500 [31:14<33:45, 11.07s/it]Transaction failed and will be retried in 1.0664596155540813s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 0.905994987133719s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 0.9203419566865793s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Querying graph:  65%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                                           | 327/500 [32:55<27:46,  9.63s/it]Transaction failed and will be retried in 1.1553272421996872s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 1.1698730820247614s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 0.8984060817307774s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Querying graph:  66%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                                         | 331/500 [33:23<17:06,  6.07s/it]Transaction failed and will be retried in 1.1801854726175158s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 0.8194019431539319s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Querying graph:  71%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                           | 356/500 [37:11<18:05,  7.54s/it]Transaction failed and will be retried in 0.9901141354454268s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 1.0835156897572673s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 1.0810736156372618s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 0.9963136159403556s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Querying graph:  72%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                          | 359/500 [37:52<22:57,  9.77s/it]Transaction failed and will be retried in 0.9012305518899376s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 0.9527155106587923s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Querying graph:  73%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                      | 366/500 [38:54<12:01,  5.39s/it]Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (geneSym, geneSym) { ... }} {position: line: 3, column: 1, offset: 51} for query: "WITH 'chd7' AS geneSym, 'progeria' AS diseaseTerm\n\nCALL {\n  WITH geneSym\n  MATCH (g:Gene)\n  WHERE g.approvedSymbol IS NOT NULL AND toLower(g.approvedSymbol) = geneSym\n  RETURN g\n  UNION\n  WITH geneSym\n  MATCH (g:HumanGene)\n  WHERE g.approvedSymbol IS NOT NULL AND toLower(g.approvedSymbol) = geneSym\n  RETURN g\n}\nWITH DISTINCT g, diseaseTerm\nORDER BY g.id\nLIMIT 1\n\nCALL {\n  WITH diseaseTerm\n  MATCH (d:Disease)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n  UNION\n  WITH diseaseTerm\n  MATCH (d:DiseaseOrPhenotypicFeature)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n  UNION\n  WITH diseaseTerm\n  MATCH (d:`Mondo.Disease`)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n  UNION\n  WITH diseaseTerm\n  MATCH (d:`Orphanet.Disease`)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n  UNION\n  WITH diseaseTerm\n  MATCH (d:`Efo.Disease`)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n  UNION\n  WITH diseaseTerm\n  MATCH (d:`Doid.Disease`)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n  UNION\n  WITH diseaseTerm\n  MATCH (d:`Ncit.Disease`)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n}\nWITH g, collect(DISTINCT d) AS diseases\nUNWIND (CASE WHEN size(diseases) = 0 THEN [NULL] ELSE diseases END) AS d\nOPTIONAL MATCH (g)-[:IS_PART_OF]->(assoc)<-[:IS_PART_OF]-(d)\nWITH\n  g,\n  [x IN diseases WHERE x IS NOT NULL | {id: x.id, name: x.name, labels: labels(x), source: x.source}] AS matched_diseases,\n  collect(DISTINCT assoc) AS rawAssocs\nWITH\n  g,\n  matched_diseases,\n  [a IN rawAssocs\n   WHERE a IS NOT NULL AND any(l IN labels(a) WHERE l IN [\n     'GeneToDiseaseAssociation',\n     'Literature.GeneToDiseaseAssociation',\n     'AnimalModel.GeneToDiseaseAssociation',\n     'RnaExpression.GeneToDiseaseAssociation',\n     'GeneticAssociation.GeneToDiseaseAssociation',\n     'SomaticMutation.GeneToDiseaseAssociation',\n     'KnownDrug.GeneToDiseaseAssociation',\n     'AffectedPathway.GeneToDiseaseAssociation'\n   ])\n   | {id: a.id, score: a.score, source: a.source, literature: a.literature, labels: labels(a)}\n  ] AS associations\nRETURN\n  g.id AS gene_id,\n  g.approvedSymbol AS gene_symbol,\n  size(matched_diseases) AS matched_disease_nodes,\n  matched_diseases,\n  size(associations) AS association_count,\n  CASE WHEN size(associations) = 0 THEN true ELSE false END AS not_associated,\n  associations\nLIMIT 1"
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (diseaseTerm, diseaseTerm, diseaseTerm, diseaseTerm, diseaseTerm, diseaseTerm, diseaseTerm) { ... }} {position: line: 18, column: 1, offset: 365} for query: "WITH 'chd7' AS geneSym, 'progeria' AS diseaseTerm\n\nCALL {\n  WITH geneSym\n  MATCH (g:Gene)\n  WHERE g.approvedSymbol IS NOT NULL AND toLower(g.approvedSymbol) = geneSym\n  RETURN g\n  UNION\n  WITH geneSym\n  MATCH (g:HumanGene)\n  WHERE g.approvedSymbol IS NOT NULL AND toLower(g.approvedSymbol) = geneSym\n  RETURN g\n}\nWITH DISTINCT g, diseaseTerm\nORDER BY g.id\nLIMIT 1\n\nCALL {\n  WITH diseaseTerm\n  MATCH (d:Disease)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n  UNION\n  WITH diseaseTerm\n  MATCH (d:DiseaseOrPhenotypicFeature)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n  UNION\n  WITH diseaseTerm\n  MATCH (d:`Mondo.Disease`)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n  UNION\n  WITH diseaseTerm\n  MATCH (d:`Orphanet.Disease`)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n  UNION\n  WITH diseaseTerm\n  MATCH (d:`Efo.Disease`)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n  UNION\n  WITH diseaseTerm\n  MATCH (d:`Doid.Disease`)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n  UNION\n  WITH diseaseTerm\n  MATCH (d:`Ncit.Disease`)\n  WHERE d.name IS NOT NULL AND toLower(d.name) CONTAINS diseaseTerm\n  RETURN d\n}\nWITH g, collect(DISTINCT d) AS diseases\nUNWIND (CASE WHEN size(diseases) = 0 THEN [NULL] ELSE diseases END) AS d\nOPTIONAL MATCH (g)-[:IS_PART_OF]->(assoc)<-[:IS_PART_OF]-(d)\nWITH\n  g,\n  [x IN diseases WHERE x IS NOT NULL | {id: x.id, name: x.name, labels: labels(x), source: x.source}] AS matched_diseases,\n  collect(DISTINCT assoc) AS rawAssocs\nWITH\n  g,\n  matched_diseases,\n  [a IN rawAssocs\n   WHERE a IS NOT NULL AND any(l IN labels(a) WHERE l IN [\n     'GeneToDiseaseAssociation',\n     'Literature.GeneToDiseaseAssociation',\n     'AnimalModel.GeneToDiseaseAssociation',\n     'RnaExpression.GeneToDiseaseAssociation',\n     'GeneticAssociation.GeneToDiseaseAssociation',\n     'SomaticMutation.GeneToDiseaseAssociation',\n     'KnownDrug.GeneToDiseaseAssociation',\n     'AffectedPathway.GeneToDiseaseAssociation'\n   ])\n   | {id: a.id, score: a.score, source: a.source, literature: a.literature, labels: labels(a)}\n  ] AS associations\nRETURN\n  g.id AS gene_id,\n  g.approvedSymbol AS gene_symbol,\n  size(matched_diseases) AS matched_disease_nodes,\n  matched_diseases,\n  size(associations) AS association_count,\n  CASE WHEN size(associations) = 0 THEN true ELSE false END AS not_associated,\n  associations\nLIMIT 1"
# Querying graph:  75%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                 | 376/500 [39:16<04:48,  2.32s/it]Transaction failed and will be retried in 1.168416573853907s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Transaction failed and will be retried in 0.9410310617973617s (The allocation of an extra 2.0 MiB would use more than the limit 21.0 GiB. Currently using 21.0 GiB. dbms.memory.transaction.total.max threshold reached)
# Querying graph:  92%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                    | 462/500 [48:24<05:37,  8.88s/it]

# %%
results = process_results(todo, llm_answers, cypher_results)
with open("../Thinking_models_only/results/biomix14_adapted-evaluations_ThinkingModels.json", "w", encoding="utf-8") as f:
    json.dump(results, f, indent=4)

# %%
results_df = pd.DataFrame(results)
results_df["has_interaction"] = results_df["count"] > 0
results_df = results_df.merge(questions, left_on="question", right_on="text", how="left")
results_df = results_df.drop(columns=["text"])
results_df['direct'] = ~results_df['question'].str.contains("is not associated")
results_df["answer"] = results_df["direct"] == results_df["has_interaction"]

# %%
results_df.to_excel("../Thinking_models_only/results/biomix14_adapted-evaluations_ThinkingModels.xlsx", index=False)
results_df

# %%
# Calculate the fraction of correct answers for each model
accuracy_df = results_df.groupby('model').apply(lambda x: (x['label'] == x['answer']).mean()).reset_index()
accuracy_df.columns = ['model', 'accuracy']
accuracy_df

# %%
import pandas as pd

# %%
results_df = pd.read_excel("../Thinking_models_only/results/biomix14_adapted-evaluations_ThinkingModels.xlsx")

# %%
accuracy_df = results_df.groupby('model').apply(lambda x: (x['label'] == x['answer']).mean()).reset_index()
accuracy_df.columns = ['model', 'accuracy']
accuracy_df
# Out:
# /var/folders/xh/h0s_k2yj7vl5lcl4dyjlstxr0000gp/T/ipykernel_35865/3139181959.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   accuracy_df = results_df.groupby('model').apply(lambda x: (x['label'] == x['answer']).mean()).reset_index()
#                                model  accuracy
# 0    claude-sonnet-4-5-20250929|high      0.91
# 1  claude-sonnet-4-5-20250929|medium      0.95
# 2                             gpt-4o      0.90
# 3            gpt-5.2-2025-12-11|high      0.72
# 4          gpt-5.2-2025-12-11|medium      0.75
